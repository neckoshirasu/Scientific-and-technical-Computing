# %% [markdown]
# ## 復習問題
#
# 以下は課題ではないが，今回の内容を復習するための問題集である．

# %% [markdown]
# - listとtupleについて違いを説明せよ。
# - for文とwhile文について違いを説明せよ。
# - numpy.ndarrayとlistについて違いを説明せよ。
# - math.sqrtとcmath.sqrtについて違いを説明せよ。
# - rangeとlistについて違いを説明せよ。
# - リストの+=とextend()について違いを説明せよ。
# - if文とelif文について違いを説明せよ。
# - sum()とnp.sum()について違いを説明せよ。
# - スライスとインデキシングについて違いを説明せよ。
# - break文とcontinue文について違いを説明せよ。
# - assert文とif文について違いを説明せよ。
# - print()と式評価について違いを説明せよ。
# - Docstringとコメントについて違いを説明せよ。
# - type()とisinstance()について違いを説明せよ。
# - keyword引数と位置引数について違いを説明せよ。
# - インタラクティブ実行環境とスクリプト実行環境について違いを説明せよ。
# - リスト生成の際の内包表記とfor文について違いを説明せよ。
# - mathモジュールとnumpyモジュールについて違いを説明せよ。
# - 四則演算と論理演算について違いを説明せよ。
# - リストと2次元リストについて違いを説明せよ。
# - in演算子と比較演算子について違いを説明せよ。
# - タプルとリストのイミュータブル性について違いを説明せよ。
# - 標準出力とエラーメッセージについて違いを説明せよ。
# - numpyのshapeとndimについて違いを説明せよ。
# - リストのスライシングとタプルのスライシングについて違いを説明せよ。
# - python関数の値渡しと参照渡しについて違いを説明せよ。
# - plt.figure()とfig.subplots()について違いを説明せよ。
# - ax.plot()とax.scatter()について違いを説明せよ。
# - plt.show()とplt.savefig()について違いを説明せよ。
# - line styleとmarker styleについて違いを説明せよ。
# - ax.set_xlabel()とax.set_ylabel()について違いを説明せよ。
# - 軸のカスタマイズと線のスタイル変更について違いを説明せよ。

# %% [markdown]
# - 折れ線グラフを描画するコードを作成せよ。
#    - X軸に0から10までの整数、Y軸にそれらの値の2乗をプロットすること。
# - 複数の折れ線グラフを1つの図に描画するコードを作成せよ。
#    - 2つの異なる関数（$y = x^2$ と $y = 2x + 1$）を同じグラフにプロットすること。
# - 2次元散布図を描画するコードを作成せよ。
#    - X軸とY軸にランダムな数値を使用し、散布図を作成すること。
# - 折れ線のスタイルを変更してプロットするコードを作成せよ。
#    - 折れ線の色、線の種類（破線など）、線幅をカスタマイズしたプロットを作成すること。
# - グラフにタイトルと軸ラベルを追加するコードを作成せよ。
#    - X軸に「時間（秒）」、Y軸に「距離（メートル）」のラベルをつけ、タイトルを「距離-時間グラフ」とする。
# - サブプロットを使って2つのグラフを並べて描画するコードを作成せよ。
#    - 左のサブプロットに線グラフ、右のサブプロットに散布図を描画すること。
# - 対数スケールのプロットを作成するコードを作成せよ。
#    - X軸が対数スケールで、Y軸が通常スケールのプロットを作成すること。
# - データのヒストグラムを描画するコードを作成せよ。
#    - NumPyを用いてランダムな正規分布に従うデータを生成し、そのヒストグラムをプロットすること。
# - 複数の異なる線のスタイルを用いたグラフを描画するコードを作成せよ。
#    - `ax.plot()`を用いて、3種類の異なる線のスタイル（例：破線、点線、太線）を持つ3つの異なるグラフを同じプロットに描画すること。
# - 凡例を追加した折れ線グラフを作成するコードを作成せよ。
#    - 2つの関数（$y = \sin(x)$ と $y = \cos(x)$）をプロットし、それぞれの凡例を追加すること。

# %% [markdown]
# - `matplotlib`を使って、0から10までのx軸に対して、y = x^2 の折れ線グラフを描画するコードを作成せよ。
# - リスト`x = [1, 2, 3, 4, 5]`と`y = [10, 20, 30, 40, 50]`を使って、2次元散布図を作成するコードを作成せよ。
# - `matplotlib`でサブプロットを作成し、1つ目にsin、2つ目にcosを描画するコードを作成せよ。
# - `np.linspace(0, 10, 100)`をx軸、`y = sin(x)`をy軸にして、折れ線グラフを描画し、グラフにラベルとタイトルを付けるコードを作成せよ。
# - 2つの異なる線のスタイル（例えば実線と破線）で折れ線グラフを同じプロット内に描画するコードを作成せよ。
# - 折れ線グラフに凡例を追加し、`ax.legend()`を使って適切な説明をつけるコードを作成せよ。
# - ランダムな数値を生成し、そのヒストグラムを`matplotlib`で描画するコードを作成せよ。
# - `fig.subplots()`を使用して、3×1のレイアウトのサブプロットを作成し、それぞれに異なるデータをプロットするコードを作成せよ。
# - を使ってランダムなデータを生成し、それを散布図として描画し、x軸とy軸にラベルをつけるコードを作成せよ。
# - 対数スケールを使って、x軸を対数スケールにし、y軸は通常スケールで折れ線グラフを描画するコードを作成せよ。

# %% [markdown]
# - Pythonでは、変数に代入する際に型を明示的に指定する必要がある。
#   <!-- ×：Pythonは動的型付け言語であり、型の指定は不要 -->
#
# - Jupyter Notebookでは、セルの最後に変数名だけを書けば、その値が表示される。
#   <!-- ○：セルの最後の式は自動的に表示される -->
#
# - Pythonの`range()`関数は、Python 3ではリストを返す。
#   <!-- ×：Python 3ではイテレータオブジェクトを返す -->
#
# - リストのインデックスに負の値を指定すると、リストの先頭からアクセスする。
#   <!-- ×：負のインデックスは末尾からアクセスする -->
#
# - `sum = 0`とすると、以降`sum()`関数は使えなくなる可能性がある。
#   <!-- ○：組み込み関数と同名の変数を定義すると、関数が上書きされる -->
#
# - Pythonの`if`文では、インデントがなくても正しく動作する。
#   <!-- ×：Pythonではインデントが文法上必須 -->
#
# - `enumerate()`を使うと、リストのインデックスと要素を同時に取得できる。
#   <!-- ○：インデックスと要素をタプルで取得できる -->
#
# - Pythonでは、関数の返り値を複数指定することはできない。
#   <!-- ×：複数の返り値をタプルとして返すことができる -->
#
# - NumPyの`ndarray`は、すべての要素が同じ型でなければならない。
#   <!-- ○：NumPyの配列は同一型で構成される -->
#
# - NumPyのスライシングで得られる部分配列は、元の配列とは独立したコピーである。
#   <!-- ×：スライシングは参照（view）であり、元の配列とメモリを共有する -->
#
#
#
#
# - Pythonでは、`#`で始まる行はコメントとして扱われる。
#   <!-- ○：Pythonでは`#`以降はコメント -->
#
# - Jupyter Notebookでは、複数行コメントは`'''`や`"""`で囲むことで記述できる。
#   <!-- ○：複数行コメントは三重クォートで囲む -->
#
# - Pythonの`print()`関数は、デフォルトで改行を含まない。
#   <!-- ×：デフォルトでは改行される -->
#
# - `print("Hello", end="")`とすると、改行されずに次の出力が続く。
#   <!-- ○：end=""で改行を抑制 -->
#
# - Pythonでは、整数と文字列を直接連結することができる。
#   <!-- ×：型変換（str()など）が必要 -->
#
# - `range(5, -5)`は、5から-4までの数列を生成する。
#   <!-- ×：ステップが指定されていないため空になる -->
#
# - `range(10, 0, -1)`は、10から1までの数列を生成する。
#   <!-- ○：ステップが-1で逆順 -->
#
# - `range()`オブジェクトは、必要なときに要素を生成するためメモリ効率が良い。
#   <!-- ○：イテレータであるため -->
#
# - `list1 + list2`は、2つのリストを連結する操作である。
#   <!-- ○：リストの連結 -->
#
# - `list1 * 3`は、リストの要素を3回繰り返す操作である。
#   <!-- ○：リストの反復 -->
#
# - `max([])`は、空リストに対して最大値を求めるためエラーになる。
#   <!-- ○：空リストには適用できない -->
#
# - Pythonでは、文字列はリストと同様にインデックスでアクセスできる。
#   <!-- ○：文字列はシーケンス型 -->
#
# - `str(10.5)`は、数値を文字列に変換する操作である。
#   <!-- ○：str()で文字列化 -->
#
# - `a = [1, 2, 3]; a[-1]`は、リストの最初の要素を返す。
#   <!-- ×：最後の要素を返す -->
#
# - `a = [[1, 2], [3, 4]]; a[0][1]`は、2を返す。
#   <!-- ○：2次元リストのアクセス -->
#
# - `a[0, 1]`は、リストに対しては正しいインデックス指定である。
#   <!-- ×：リストではタプルインデックスは使えない -->
#
# - `if a > 0:`のように、Pythonでは条件文にインデントが必要である。
#   <!-- ○：インデントは文法上必須 -->
#
# - `if 0 <= a <= 10:`は、Pythonで正しい範囲指定の条件文である。
#   <!-- ○：Pythonでは連鎖比較が可能 -->
#
# - `enumerate()`は、インデックスと要素を同時に取得するための関数である。
#   <!-- ○：インデックス付き反復 -->
#
# - `while True:`は、無限ループを作成する構文である。
#   <!-- ○：条件が常にTrue -->

# %% [markdown]
# 以下は「Jupyter Notebookの基本操作」についての説明である。間違っているものを選べ。
#
# - A. セルの最後に変数名だけを書くと、その値が表示される。
# - B. セルの実行は「Shift + Enter」で行える。
# - C. セル内のコメントは `#` を使って記述する。
# - D. セルの実行順序は常に上から順番に固定されている。
# <!-- 正解: D — Notebookではセルの実行順序は自由であり、順番に依存しない -->
#
# 以下は「Pythonの変数と型」についての説明である。間違っているものを選べ。
#
# - A. Pythonでは変数に型を明示的に指定する必要はない。
# - B. `type()`関数を使うと変数の型を確認できる。
# - C. 異なる型の値を同じ変数に代入することはできない。
# - D. `str()`を使うと数値を文字列に変換できる。
# <!-- 正解: C — Pythonでは動的型付けのため、異なる型の値を同じ変数に代入できる -->
#
# 以下は「リストの基本操作」についての説明である。間違っているものを選べ。
#
# - A. リストは `[]` を使って定義する。
# - B. リストのインデックスは0から始まる。
# - C. 負のインデックスは先頭からのアクセスを意味する。
# - D. `append()`を使うとリストに要素を追加できる。
# <!-- 正解: C — 負のインデックスは末尾からのアクセス -->
#
# 以下は「range()関数」についての説明である。間違っているものを選べ。
#
# - A. `range(5)`は0から4までの整数を生成する。
# - B. `range()`はPython 3ではリストを返す。
# - C. `range(a, b, c)`ではcがステップ幅を表す。
# - D. `list(range(3))`は[0, 1, 2]を返す。
# <!-- 正解: B — Python 3ではrangeはイテレータオブジェクトを返す -->
#
# 以下は「制御文 if の構文」についての説明である。間違っているものを選べ。
#
# - A. `if`文の条件がTrueのとき、インデントされたブロックが実行される。
# - B. `else`は省略可能である。
# - C. Pythonではインデントは任意である。
# - D. `elif`は複数の条件を順に評価するために使う。
# <!-- 正解: C — Pythonではインデントは文法上必須 -->
#
# 以下は「論理演算子」についての説明である。間違っているものを選べ。
#
# - A. `and`は両方の条件がTrueのときにTrueになる。
# - B. `or`はどちらかの条件がTrueのときにTrueになる。
# - C. `not`は条件を反転する。
# - D. `and`はPythonでは使えないため、代わりに`&&`を使う。
# <!-- 正解: D — Pythonでは`and`を使い、`&&`は使えない -->
#
# 以下は「関数定義と返り値」についての説明である。間違っているものを選べ。
#
# - A. Pythonでは`def`を使って関数を定義する。
# - B. 関数の返り値は1つしか指定できない。
# - C. `return`文で返り値を指定する。
# - D. 複数の返り値はタプルとして返される。
# <!-- 正解: B — Pythonでは複数の返り値を返すことができる -->
#
# 以下は「NumPyのndarray」についての説明である。間違っているものを選べ。
#
# - A. ndarrayのすべての要素は同じ型である。
# - B. ndarrayはリストと同様に異なる型の要素を持てる。
# - C. `np.array()`でリストからndarrayを作成できる。
# - D. `.dtype`で要素の型を確認できる。
# <!-- 正解: B — ndarrayはすべての要素が同じ型でなければならない -->
#
#  以下は「ndarrayのスライシング」についての説明である。間違っているものを選べ。
#
# - A. スライシングは元のndarrayのコピーを返す。
# - B. スライシングは参照（view）である。
# - C. スライシングで得た部分に代入すると元の配列が変更される。
# - D. `.copy()`を使うと独立したコピーが得られる。
# <!-- 正解: A — スライシングはコピーではなく参照（view） -->

# %% [markdown]
# - 以下は「リストの連結」についての説明である．間違いを指摘せよ：
#   「リストの連結には`append()`を使う。」
#   <!-- 解答例：`append()`は要素の追加。連結には`+`演算子または`extend()`を使う。 -->
#
# - 以下は「enumerate関数」についての説明である．間違いを指摘せよ：
#   「enumerateを使うと、リストの要素だけを取得できる。」
#   <!-- 解答例：enumerateはインデックスと要素の両方を取得する。 -->
#
# - 以下は「関数の返り値」についての説明である．間違いを指摘せよ：
#   「Pythonでは、関数の返り値は1つしか指定できない。」
#   <!-- 解答例：複数の返り値をタプルとして返すことができる。 -->
#
# - 以下は「NumPyのndarray」についての説明である．間違いを指摘せよ：
#   「NumPyのndarrayは、異なる型の要素を含むことができる。」
#   <!-- 解答例：ndarrayの要素はすべて同じ型でなければならない。 -->
#
# - 以下は「NumPyのスライシング」についての説明である．間違いを指摘せよ：
#   「NumPyのスライシングで得られる部分配列は、元の配列とは独立したコピーである。」
#   <!-- 解答例：スライシングは参照（view）であり、元の配列とメモリを共有する。 -->

# %% [markdown]
# - 以下は「np.zeros()」についての説明である．間違いを指摘せよ：
#   「np.zeros((3, 4))は、3列4行のゼロ行列を生成する。」
#   <!-- 解答例：np.zeros((3, 4))は3行4列の行列を生成する。行が先、列が後。 -->
#
# - 以下は「np.ones_like()」についての説明である．間違いを指摘せよ：
#   「np.ones_like(a)は、aと同じ形で、すべての要素が0のndarrayを生成する。」
#   <!-- 解答例：np.ones_like()はすべての要素が1のndarrayを生成する。 -->
#
# - 以下は「np.full()」についての説明である．間違いを指摘せよ：
#   「np.full((2, 3), 7)は、2列3行のndarrayを生成し、すべての要素が7になる。」
#   <!-- 解答例：2行3列のndarrayを生成する。行が先、列が後。 -->
#
# - 以下は「np.arange()」についての説明である．間違いを指摘せよ：
#   「np.arange(0, 10, 2)は、0から10までの偶数を含むndarrayを返す。」
#   <!-- 解答例：10は含まれない。返されるのは[0, 2, 4, 6, 8]。 -->
#
# - 以下は「np.linspace()」についての説明である．間違いを指摘せよ：
#   「np.linspace(0, 1, 5)は、0から1までの範囲を4等分したndarrayを返す。」
#   <!-- 解答例：np.linspace(0, 1, 5)は5等分された5つの値を返す。 -->
#
# - 以下は「np.random.default_rng().integers()」についての説明である．間違いを指摘せよ：
#   「integers(10, size=(2, 3))は、0から10までの整数を含む2×3のndarrayを返す。」
#   <!-- 解答例：10は含まれない。範囲は0以上10未満。 -->
#
# - 以下は「np.random.uniform()」についての説明である．間違いを指摘せよ：
#   「uniform(0.0, 1.0, size=(2, 2))は、0.0以上1.0以下の一様乱数を生成する。」
#   <!-- 解答例：1.0は含まれない。範囲は[0.0, 1.0) -->
#
# - 以下は「ndarrayのreshape()」についての説明である．間違いを指摘せよ：
#   「reshape(-1, 2)は、元のndarrayの要素数が偶数でなければエラーになる。」
#   <!-- 解答例：要素数が2の倍数であれば reshape(-1, 2) は可能。偶数でなくても2で割り切れればOK。 -->
#
# - 以下は「np.vstack()」についての説明である．間違いを指摘せよ：
#   「np.vstack((a, b))は、aとbの列数が異なっていても縦に連結できる。」
#   <!-- 解答例：縦方向に連結するには列数が一致している必要がある。 -->
#
# - 以下は「np.hstack()」についての説明である．間違いを指摘せよ：
#   「np.hstack((a, b))は、aとbの行数が異なっていても横に連結できる。」
#   <!-- 解答例：横方向に連結するには行数が一致している必要がある。 -->

# %% [markdown]
# - 以下は「1次元ndarrayのインデキシング」についての説明である．間違いを指摘せよ：
#   「a = np.arange(5); a[5]は最後の要素を返す。」
#   <!-- 解答例：インデックス5は範囲外。最後の要素はa[4]。 -->
#
# - 以下は「負のインデックス」についての説明である．間違いを指摘せよ：
#   「a[-1]は最初の要素を返す。」
#   <!-- 解答例：a[-1]は最後の要素を返す。最初の要素はa[0]。 -->
#
# - 以下は「インデックスの順序」についての説明である．間違いを指摘せよ：
#   「a[i, j]では、iが列番号で、jが行番号である。」
#   <!-- 解答例：iが行番号、jが列番号。行が先、列が後。 -->
#
# - 以下は「スライシングとインデキシングの違い」についての説明である．間違いを指摘せよ：
#   「a[0:]とa[0, :]は同じndarrayを返す。」
#   <!-- 解答例：a[0:]は2次元ndarray、a[0, :]は1次元ndarrayの行を返す。shapeが異なる。 -->
#
# - 以下は「インデキシングによる要素の取得」についての説明である．間違いを指摘せよ：
#   「a[1, 2]は、aの1行目2列目の要素を返す。」
#   <!-- 解答例：インデックスは0始まり。a[1, 2]は2行目の3列目。 -->
#
# - 以下は「インデキシングと型」についての説明である．間違いを指摘せよ：
#   「a[0, 0]の型は常にndarrayである。」
#   <!-- 解答例：3次元以上のndarrayの場合．2次元ndarrayの場合にはスカラーとなる． -->
#
# - 以下は「インデキシングによる行列の操作」についての説明である．間違いを指摘せよ：
#   「a[:, 0]は、aの1行目を取得する操作である。」
#   <!-- 解答例：a[:, 0]は1列目を取得する。1行目はa[0, :]。 -->
