# %% [markdown]
# ## 復習問題
#
# 以下は課題ではないが，今回の内容を復習するための問題集である．

# %% [markdown]
# 1. 逆行列とLU分解について違いを説明せよ。
# 2. 部分ピボット選択と完全ピボット選択について違いを説明せよ。
# 3. Jacobi法とGauss-Seidel法について違いを説明せよ。
# 4. SOR法とGauss-Seidel法について違いを説明せよ。
# 5. 直接法と反復法について違いを説明せよ。
# 6. 行列式の計算と連立方程式の解法について違いを説明せよ。
# 7. np.linalg.solve()とnp.linalg.inv()の違いを説明せよ。
# 8. 正定値対称行列と一般の行列の違いを説明せよ。
# 9. 帯行列と巡回行列の違いを説明せよ。
# 10. LU分解とCholesky分解について違いを説明せよ。
# 15. 前進消去と後退代入の違いを説明せよ。
# 24. LU分解とQR分解について違いを説明せよ。
# 25. 行列の対称性と行列の正定値性について違いを説明せよ。
# 26. ノルムの性質と条件数の性質について違いを説明せよ。
# 29. LU分解を用いた行列式の計算と定義に基づく行列式の計算について違いを説明せよ。
# 30. 対称行列と非対称行列について違いを説明せよ。

# %% [markdown]
# 以下はLU分解についての説明である．間違いを指摘せよ。
#
# 「LU分解は、行列Aを上三角行列Lと下三角行列Uの積として分解する手法であり、Lは対角要素が1である。」
#
#
# <!-- 間違い：上三角行列Lと下三角行列Uが逆になっている。
# 正しい説明：LU分解では、行列Aは下三角行列Lと上三角行列Uに分解され、Lは対角要素が1である。 -->
#
#
#
# 以下はJacobi法についての説明である．間違いを指摘せよ。
#
# 「Jacobi法は、各変数を繰り返し更新し、計算を進める反復法で、Gauss-Seidel法よりも収束が速い。」
#
#
# <!-- 間違い：Jacobi法はGauss-Seidel法よりも収束が速いという点が誤り。
# 正しい説明：Jacobi法は、Gauss-Seidel法よりも一般的に収束が遅い。 -->
#
#
#
# 以下は行列式の計算についての説明である．間違いを指摘せよ。
#
# 「行列式が0であれば、連立方程式は解を持つことが保証される。」
#
#
# <!-- 間違い：行列式が0であれば解を持つという点が誤り。
# 正しい説明：行列式が0であれば、連立方程式は一般的に一意解を持たないことを意味する。 -->
#
#
#
# 以下はGaussの消去法についての説明である．間違いを指摘せよ。
#
# 「ピボット選択なしGaussの消去法は、行列の全ての対角要素が0である場合にも使用できる。」
#
#
# <!-- 間違い：全ての対角要素が0でも使用できるという点が誤り。
# 正しい説明：Gaussの消去法は対角要素が0の場合には直接適用できず、ピボット選択が必要になる。 -->
#
#
#
# 以下は条件数についての説明である．間違いを指摘せよ。
#
# 「条件数が小さい行列は数値的に不安定であり、逆行列を求める際に誤差が大きくなる。」
#
#
# <!-- 間違い：条件数が小さい行列は数値的に不安定という点が誤り。
# 正しい説明：条件数が小さい行列は数値的に安定しており、逆行列を求める際の誤差も小さい。条件数が大きいと不安定になる。 -->

# %% [markdown]
# 以下は連立方程式の解の精度についての説明である．間違いを指摘せよ。
#
# 「連立方程式の解を求める際、右辺ベクトルに小さな誤差が含まれていても、解に影響を与えることはない。」
#
# <!--  解答例
# 間違い：右辺ベクトルに小さな誤差が含まれても影響を与えないという点が誤り。
# 正しい説明：右辺ベクトルに誤差が含まれると、連立方程式の解にも影響が出ることがあり、特に条件数が大きい場合は誤差が増幅される可能性がある。 -->
#
#
#
# 以下は条件数についての説明である．間違いを指摘せよ。
#
# 「条件数が1に近い行列は数値的に不安定であり、解を求める際に大きな誤差が発生する可能性がある。」
#
# <!--  解答例
# 間違い：条件数が1に近い行列は数値的に不安定という点が誤り。
# 正しい説明：条件数が1に近い行列は数値的に安定であり、誤差が発生する可能性が低い。条件数が大きくなるほど数値的に不安定になる。 -->
#
#
#
# 以下は条件数による解の誤差評価についての説明である．間違いを指摘せよ。
#
# 「条件数が大きい行列は、右辺ベクトルに誤差が含まれても、解への影響は小さい。」
#
# <!--  解答例
# 間違い：条件数が大きい行列では解への影響が小さいという点が誤り。
# 正しい説明：条件数が大きい行列では、右辺ベクトルに含まれる誤差が解に大きな影響を与える可能性が高い。 -->
#
#
#
# 以下は行列のノルムについての説明である．間違いを指摘せよ。
#
# 「行列のノルムは、行列の条件数とは無関係であり、解の精度に影響を与えることはない。」
#
# <!--  解答例
# 間違い：行列のノルムは条件数とは無関係という点が誤り。
# 正しい説明：行列のノルムは条件数の計算に関係があり、行列の性質によって解の精度に影響を与えることがある。 -->
#
#
#
# 以下は連立方程式の解の誤差についての説明である．間違いを指摘せよ。
#
# 「条件数が大きい行列の場合でも、係数行列に誤差が含まれていない限り、解の誤差は小さい。」
#
# <!--  解答例
# 間違い：条件数が大きい行列では解の誤差は小さいという点が誤り。
# 正しい説明：条件数が大きい行列では、右辺や係数行列に誤差が含まれていなくても、計算の丸め誤差が解に大きく影響を与える可能性がある。 -->

# %% [markdown]
# 以下は行列のノルムについての説明である．間違いを指摘せよ。
#
# 「行列のノルムは、行列の全要素の和を基に計算されるため、行列の要素が多いほどノルムは必然的に大きくなる。」
#
# <!--  解答例
# 間違い：行列の全要素の和でノルムが計算されるという点が誤り。
# 正しい説明：行列ノルムには複数の定義があり、一般的には行列の要素の和ではなく、行や列の最大値や特定のベクトルに対する作用素ノルムに基づいて計算される。 -->
#
#
#
# 以下はフロベニウスノルムについての説明である．間違いを指摘せよ。
#
# 「フロベニウスノルムは行列の全要素の絶対値の最大値で定義され、行列の大きさに依存する。」
#
# <!--  解答例
# 間違い：フロベニウスノルムは絶対値の最大値で定義されるという点が誤り。
# 正しい説明：フロベニウスノルムは行列の全要素の二乗和の平方根として定義され、行列の個々の要素の大きさに依存する。 -->
#
#
#
# 以下は作用素ノルムについての説明である．間違いを指摘せよ。
#
# 「作用素ノルムは、行列に含まれる最大要素を基に計算されるため、行列の最大要素が大きいほど作用素ノルムも大きくなる。」
#
# <!--  解答例
# 間違い：作用素ノルムは最大要素を基に計算されるという点が誤り。
# 正しい説明：作用素ノルムは、行列がベクトルに作用した際のベクトルの変化の大きさに基づいて計算されるため、行列の最大要素ではなく、行列全体の作用が重要である。 -->
#
#
#
# 以下は行列の1ノルムについての説明である．間違いを指摘せよ。
#
# 「行列の1ノルムは、行列のすべての行の要素の和を計算して、その最大値を取ったものである。」
#
# <!--  解答例
# 間違い：1ノルムは行の要素の和を取るという点が誤り。
# 正しい説明：行列の1ノルムは、各列の要素の絶対値の和を計算し、その中で最大のものを取る。 -->
#
#
#
# 以下は行列の無限大ノルムについての説明である．間違いを指摘せよ。
#
# 「行列の無限大ノルムは、行列の全要素の絶対値の合計を取ることで計算される。」
#
# <!--  解答例
# 間違い：無限大ノルムは全要素の絶対値の合計という点が誤り。
# 正しい説明：行列の無限大ノルムは、各行の要素の絶対値の和を計算し、その中で最大のものを取る。 -->

# %% [markdown]
# 以下はLU分解についての説明である．正しいものを選べ。
#
# 1. LU分解では、行列Aは対角行列Lと上三角行列Uに分解される。
# 2. LU分解では、行列Aは単位下三角行列Lと上三角行列Uに分解される。
# 3. LU分解では、行列Aは対角行列と対称行列に分解される。
# 4. LU分解では、行列Aは下三角行列Lと正定値行列Uに分解される。
#
# <!--  解答例
# 正解: 2
# 説明: LU分解では、行列Aは単位下三角行列Lと上三角行列Uに分解される。 -->
#
#
#
# 以下はJacobi法についての説明である．正しいものを選べ。
#
# 1. Jacobi法は各変数を一度に更新するため、収束が速い。
# 2. Jacobi法は、隣接する変数を同時に更新することで収束を早める。
# 3. Jacobi法は、各変数を他の変数を固定して順次更新する。
# 4. Jacobi法は、全ての変数を同時に更新するが、他の変数の最新の値を使用しない。
#
# <!--  解答例
# 正解: 4
# 説明: Jacobi法は全ての変数を同時に更新し、他の変数の最新の値を使用しない。 -->
#
#
#
# 以下はGaussの消去法についての説明である．正しいものを選べ。
#
# 1. Gaussの消去法では、連立方程式の解を求める際にピボット選択を必ず行う。
# 2. Gaussの消去法は対称行列のみに適用可能である。
# 3. Gaussの消去法では、行列の全ての要素が同じ大きさである必要がある。
# 4. Gaussの消去法は対角要素が0でない限り適用できる。
#
# <!--  解答例
# 正解: 4
# 説明: Gaussの消去法は、対角要素が0でない限り適用できる。 -->
#
#
#
# 以下は条件数についての説明である．正しいものを選べ。
#
# 1. 条件数が大きい行列は、数値的に安定しており、解の精度が高い。
# 2. 条件数が小さい行列は、数値的に不安定で、誤差が増幅しやすい。
# 3. 条件数が1に近い行列は、数値的に安定しており、誤差が少ない。
# 4. 条件数は行列の大きさによって自動的に決まる。
#
# <!--  解答例
# 正解: 3
# 説明: 条件数が1に近い行列は数値的に安定しており、誤差が少ない。 -->
#
#
#
# 以下はフロベニウスノルムについての説明である．正しいものを選べ。
#
# 1. フロベニウスノルムは、行列の全要素の和を基に計算される。
# 2. フロベニウスノルムは、行列の全要素の二乗和の平方根で定義される。
# 3. フロベニウスノルムは、行列の対角要素のみを使って計算される。
# 4. フロベニウスノルムは、行列の最大値を使用して計算される。
#
# <!--  解答例
# 正解: 2
# 説明: フロベニウスノルムは行列の全要素の二乗和の平方根で定義される。 -->
#
#
#
# 以下は行列の1ノルムについての説明である．正しいものを選べ。
#
# 1. 1ノルムは行列の全ての行の絶対値の和を計算する。
# 2. 1ノルムは行列の全ての要素の絶対値を合計して求められる。
# 3. 1ノルムは行列の全列の絶対値の和の中で最も大きいものを選ぶ。
# 4. 1ノルムは行列の全行の絶対値の和の中で最も小さいものを選ぶ。
#
# <!--  解答例
# 正解: 3
# 説明: 1ノルムは各列の絶対値の和を計算し、その最大値を取る。 -->
#
#
#
# 以下はGauss-Seidel法についての説明である．正しいものを選べ。
#
# 1. Gauss-Seidel法は、Jacobi法と同様に全ての変数を同時に更新する。
# 2. Gauss-Seidel法は、各変数を最新の値で順次更新する。
# 3. Gauss-Seidel法は、対称行列にのみ適用可能である。
# 4. Gauss-Seidel法は、変数の更新を全て最後に行う。
#
# <!--  解答例
# 正解: 2
# 説明: Gauss-Seidel法では、各変数を最新の値で順次更新する。 -->
#
#
#
# 以下は行列式についての説明である．正しいものを選べ。
#
# 1. 行列式が0であれば、行列は必ず逆行列を持つ。
# 2. 行列式が0であれば、行列は特異である。
# 3. 行列式が正の値を取るとき、行列は常に対称行列である。
# 4. 行列式は、行列のすべての列ベクトルが独立である場合に0となる。
#
# <!--  解答例
# 正解: 2
# 説明: 行列式が0の場合、行列は特異であり、逆行列を持たない。 -->
#
#
#
# 以下は反復法についての説明である．正しいものを選べ。
#
# 1. 反復法では、有限回の反復で厳密解が得られる。
# 2. 反復法では、計算誤差が必ず増加する。
# 3. 反復法は、有限回の反復で厳密解が得られないことがある。
# 4. 反復法は、任意の行列に対して適用可能である。
#
# <!--  解答例
# 正解: 3
# 説明: 反復法では、厳密解が得られない場合もあり、収束条件が重要となる。
# 有限回の反復で厳密解が得られるのは共役勾配法である．
#  -->
#
#
#
# 以下はLU分解を用いた連立方程式の解法についての説明である．正しいものを選べ。
#
# 1. LU分解を用いた連立方程式の解法では、常に逆行列を計算する必要がある。
# 2. LU分解を用いた連立方程式の解法では、下三角行列の逆行列を用いる。
# 3. LU分解を用いた連立方程式の解法では、前進消去と後退代入を使う。
# 4. LU分解を用いた連立方程式の解法では、行列の対称性が必要である。
#
# <!--  解答例
# 正解: 3
# 説明: LU分解を用いた解法では、前進消去と後退代入が使用される。 -->

# %% [markdown]
# 以下は前進消去についての説明である．正しいものを選べ。
#
# 1. 前進消去では、対角要素をすべて0にする。
# 2. 前進消去は、行列の下三角部分をゼロにするための操作である。
# 3. 前進消去では、上三角行列を下三角行列に変換する。
# 4. 前進消去は、行列の全ての列を消去する操作である。
#
# <!--  解答例
# 正解: 2
# 説明: 前進消去は、行列の下三角部分の要素を0にして上三角行列を作成する操作です。 -->
#
#
#
# 以下は後退代入についての説明である．正しいものを選べ。
#
# 1. 後退代入は、上三角行列を用いて変数を一つずつ順に求めていく操作である。
# 2. 後退代入では、行列の全ての要素を対角行列に変換する。
# 3. 後退代入は、下三角行列を用いて解を計算する手法である。
# 4. 後退代入は、行列の列ごとに解を同時に求める操作である。
#
# <!--  解答例
# 正解: 1
# 説明: 後退代入は、上三角行列の解を一つずつ順に求めていく手法です。 -->
#
#
#
# 以下は前進消去と後退代入の手順についての説明である．正しいものを選べ。
#
# 1. 前進消去と後退代入は同時に行われ、行列全体をゼロ行列に変換する。
# 2. 前進消去では、すべての変数の解を一度に求める。
# 3. 後退代入は、前進消去によって作られた上三角行列を利用して、変数を順に解く手順である。
# 4. 前進消去と後退代入のどちらも、任意の行列に適用できる。
#
# <!--  解答例
# 正解: 3
# 説明: 後退代入は、前進消去で得られた上三角行列を使用して、変数を一つずつ順に解く手順です。 -->
#
#
#
# 以下は前進消去についての説明である．正しいものを選べ。
#
# 1. 前進消去は、対称行列にしか適用できない。
# 2. 前進消去は、下三角行列に対してのみ適用される。
# 3. 前進消去は、行列の対角要素を利用して、下三角部分の要素を消去する。
# 4. 前進消去では、行列の全ての要素がゼロであることが前提条件となる。
#
# <!--  解答例
# 正解: 3
# 説明: 前進消去では、行列の対角要素を基準にして、下三角部分の要素を0にする操作が行われます。 -->
#
#
#
# 以下は後退代入についての説明である．正しいものを選べ。
#
# 1. 後退代入は、上三角行列が得られている場合に行う手順であり、変数の値を上から順に決定していく。
# 2. 後退代入では、行列の対角成分を全て1に変換する。
# 3. 後退代入は、対称行列にしか適用できない。
# 4. 後退代入は、行列の全ての行に対して同時に解を求める。
#
# <!--  解答例
# 正解: 1
# 説明: 後退代入は、上三角行列を用いて、変数の値を上から順に決定していく手順です。 -->

# %% [markdown]
# 以下は部分ピボット選択についての説明である．正しいものを選べ。
#
# 1. 部分ピボット選択では、行列の全ての要素を並べ替えて最適なピボットを選ぶ。
# 2. 部分ピボット選択では、行列全体で列ごとに最も大きい要素をピボットとして選ぶ。
# 3. 部分ピボット選択では、部分行列の現在の列の中で最も大きい要素をピボットとして選び、行を入れ替える。
# 4. 部分ピボット選択では、列ベクトル全体を削除してピボットを決定する。
#
# <!--  解答例
# 正解: 3
# 説明: 部分ピボット選択は、現在の列の中で最も大きい要素をピボットとして選び、その行と入れ替える手法です。 -->
#
#
#
# 以下は完全ピボット選択についての説明である．正しいものを選べ。
#
# 1. 完全ピボット選択は、行列の対角成分を無視して行と列を入れ替える手法である。
# 2. 完全ピボット選択では、全ての列から最小の要素を選び、行列全体を再構築する。
# 3. 完全ピボット選択では、行と列の両方を考慮して、部分行列全体から最も大きな要素をピボットとして選び、行と列を入れ替える。
# 4. 完全ピボット選択は、行のみを入れ替え、列は固定する手法である。
#
# <!--  解答例
# 正解: 3
# 説明: 完全ピボット選択では、行と列の両方を考慮し、行列全体から最も大きな要素をピボットとして選び、行と列を入れ替えます。 -->
#
#
#
# 以下はピボット選択の目的についての説明である．正しいものを選べ。
#
# 1. ピボット選択は、数値的安定性を高めるために行われ、特に対角要素が非常に小さい場合に有効である。
# 2. ピボット選択は、計算量を減らすために行列の要素を削除する手法である。
# 3. ピボット選択は、行列の形状を変えることで計算精度を向上させる手法である。
# 4. ピボット選択は、計算誤差をゼロに近づけるために行列全体を並べ替える手法である。
#
# <!--  解答例
# 正解: 1
# 説明: ピボット選択は、数値的安定性を高めるために行われ、特に対角要素が非常に小さい場合に役立ちます。 -->
#
#
#
# 以下は部分ピボット選択と完全ピボット選択の違いについての説明である．正しいものを選べ。
#
# 1. 部分ピボット選択は行の入れ替えのみを行い、完全ピボット選択は行と列の両方の入れ替えを行う。
# 2. 部分ピボット選択は列のみを入れ替え、完全ピボット選択は行を削除する。
# 3. 部分ピボット選択では行列全体の要素を並べ替え、完全ピボット選択では対角成分を0にする。
# 4. 部分ピボット選択と完全ピボット選択は、行列の種類によって自動的に選ばれる。
#
# <!--  解答例
# 正解: 1
# 説明: 部分ピボット選択は行の入れ替えのみを行いますが、完全ピボット選択では行と列の両方を入れ替える手法です。 -->
#
#
#
# 以下はピボット選択を行うタイミングについての説明である．正しいものを選べ。
#
# 1. ピボット選択は、行列の計算が完了した後に行う。
# 2. ピボット選択は、行列の対角要素が0に近づいたときに行われる。
# 3. ピボット選択は、前進消去で除算を行う際に行われる。
# 4. ピボット選択は、行列のサイズに関係なく、常にスキップできる手法である。
#
# <!--  解答例
# 正解: 3
# 説明: ピボット選択は、前進消去でj行目の処理においてa_jjでの除算を行う際に行われる -->

# %% [markdown]
# 以下は反復法における収束判定についての説明である．正しいものを選べ。
#
# 1. 反復法は常に有限回の反復で厳密解を得ることができる。
# 2. 反復法の収束は、反復行列のノルムが1より小さい場合に保証される。
# 3. 反復法では、残差が一定値を超えると収束が保証される。
# 4. 反復法では、係数行列の要素を変更することで収束を促進する。
#
# <!--  解答例
# 正解: 2
# 説明: 反復行列Mのノルムが1より小さい場合（||M|| < 1）、反復法は収束することが保証されます。 -->
#
#
#
#
# 以下は反復法の残差の扱いについての説明である．正しいものを選べ。
#
# 1. 反復法では、残差が小さくなると解の誤差も必ず小さくなる。
# 2. 残差が小さくなると桁落ちが発生し、残差ノルムが非常に小さくなることがある。
# 3. 残差が一定以下に収束することはない。
# 4. 反復法では、残差は解の収束には影響を与えない。
#
# <!--  解答例
# 正解: 2
# 説明: 残差が小さくなると桁落ちが発生し、残差ノルムが非常に小さくなることがあります。 -->

# %% [markdown]
# 以下は**コールバックの役割**についての説明である．正しいものを選べ。
#
# 1. コールバックは、収束計算の全体を繰り返す機能であり、計算を再開する。
# 2. コールバックは、反復ごとに呼び出される関数であり、現在の解の進行状況を記録するために使用される。
# 3. コールバックは、収束後にのみ呼び出される関数であり、最終解を修正するために使用される。
# 4. コールバックは、解の収束が失敗した場合に新たな初期値を生成するために使用される。
#
# <!--  解答例
# 正解: 2
# 説明: コールバックは、各反復ごとに収束状況や解の差分を記録し、最適化が終了した後に結果をプロットするために使用されます。 -->
#
#
#
# 以下は**コールバックの実装**についての説明である．正しいものを選べ。
#
# 1. コールバックは、反復ごとに呼び出され、常に標準出力に結果を表示する。
# 2. コールバックは、反復ごとに呼び出され、必要に応じて残差や解の差分を保存する。
# 3. コールバックは、反復の最後に1回のみ呼び出され、解を初期化する。
# 4. コールバックは、反復ごとにランダムなデータを生成し、進行状況を無視する。
#
# <!--  解答例
# 正解: 2
# 説明: コールバックは、反復ごとに呼び出され、残差や解の差分を記録する役割を持っています。 -->
#
#
#
#
# 以下は**コールバッククラスの機能**についての説明である．正しいものを選べ。
#
# 1. コールバッククラスは、反復中に生成されたすべての解を削除して再初期化する。
# 2. コールバッククラスは、解の差分や残差を蓄積し、後でそのデータを取得できる。
# 3. コールバッククラスは、反復のたびに新しい解を生成して、元のデータを上書きする。
# 4. コールバッククラスは、最後の反復結果のみを保持し、中間結果は無視する。
# <!--
#  1.7.1.1. <a id='toc1_7_1_1_'></a>[解答例](#toc0_)
# 正解: 2
# 説明: コールバッククラスは、解の差分や残差を蓄積し、必要に応じてそのデータを取得して使用することができます【26:0†source】。 -->

# %% [markdown]
# 以下は**逆行列を用いない理由**についての説明である．正しいものを選べ。
#
# 1. 逆行列を用いると、計算結果が正確になるが計算量が増加するため、連立方程式の解法には適さない。
# 2. 逆行列を用いると、数値的に安定するが、解の精度が落ちるため用いない。
# 3. 逆行列を用いると、演算量が多くなり、他の効率的な解法に比べてメモリ使用量が増加するため用いない。
# 4. 逆行列は計算速度を向上させるが、誤差が蓄積するため用いない。
#
# <!--  解答例
# 正解: 3
# 説明: 逆行列を直接計算すると、演算量が多く、他の効率的な手法（例：LU分解）に比べてメモリの消費が大きくなるため、連立方程式を解く際には通常用いません。 -->
#
#
#
# 以下は**逆行列計算のデメリット**についての説明である．正しいものを選べ。
#
# 1. 逆行列の計算は高速だが、数値的な安定性が高い。
# 2. 逆行列の計算は遅く、数値的安定性も低いため、連立方程式には適さない。
# 3. 逆行列の計算は高速だが、メモリを大量に消費するため避ける。
# 4. 逆行列の計算は遅く、数値的には不安定だが、精度が向上する。
#
# <!--  解答例
# 正解: 2
# 説明: 逆行列の計算は数値的に安定しないため、連立方程式を解く際には他の解法（LU分解など）が推奨されます。 -->
#
#
#
# 以下は**逆行列を用いる代わりに他の手法を用いる理由**についての説明である．正しいものを選べ。
#
# 1. 逆行列を用いない理由は、連立方程式の解を効率的に求める他の手法がないためである。
# 2. 逆行列を計算すると精度が低下するため、他の手法を用いる。
# 3. 逆行列の計算には多くの演算が必要で、数値誤差が大きくなるため、効率的な手法が他にある。
# 4. 逆行列の計算は連立方程式の解には無関係であり、常に近似解が得られる。
#
# <!--  解答例
# 正解: 3
# 説明: 逆行列を計算すると、演算量が多く数値誤差が大きくなるため、他の効率的な手法（LU分解など）が優先されます。 -->
#
#
#
# 以下は**逆行列計算に対する代替手法**についての説明である．正しいものを選べ。
#
# 1. 逆行列の計算に代わる手法として、LU分解などが用いられるが、逆行列を計算するよりも遅い。
# 2. 逆行列の計算に代わる手法として、LU分解や反復法があり、これらは逆行列を計算するよりも効率的である。
# 3. 逆行列の計算に代わる手法は存在しないが、近似的な解を求めることはできる。
# 4. 逆行列の計算に代わる手法は、より多くのメモリを使用するため推奨されない。
#
# <!--  解答例
# 正解: 2
# 説明: 逆行列を計算する代わりに、LU分解や反復法などの効率的な手法が一般的に用いられます。 -->
#
#
#
# 以下は**逆行列を用いる場合の欠点**についての説明である．正しいものを選べ。
#
# 1. 逆行列を計算することは、常に数値的に安定しており、連立方程式を解く上で推奨される。
# 2. 逆行列の計算には大きな演算量が必要であり、連立方程式を解く際には効率が悪いため、通常は用いられない。
# 3. 逆行列を用いると、メモリ消費が少なくなるため、連立方程式を解く際には効率的である。
# 4. 逆行列の計算には誤差が含まれないため、精度の高い解が得られる。
#
# <!--  解答例
# 正解: 2
# 説明: 逆行列の計算は演算量が多く、連立方程式を解く際には他の効率的な手法が好まれます。 -->

# %% [markdown]
# 以下は**連立方程式 $ Ax = b $ を適切に解く方法**についての説明である．正しいPythonコードを選べ。
#
# 1. `x = np.linalg.inv(A) @ b`
# 2. `x = A.inv() @ b`
# 3. `x = np.linalg.solve(A, b)`
# 4. `x = A.solve(b)`
#
# <!--  解答例
# 正解: 3
# 説明: `np.linalg.solve(A, b)` は逆行列を使わずに連立方程式を解くための最適な方法です。 -->
#
#
#
# 以下は**LU分解を用いた連立方程式の解法**についての説明である．正しいPythonコードを選べ。
#
# 1. `LU, P = scipy.linalg.lu_factor(A); x = scipy.linalg.lu_solve((LU, P), b)`
# 1. `LU, P = scipy.linalg.lu_factor(A); x = scipy.linalg.solve(LU, P)`
# 3. `LU, P = scipy.linalg.lu(A); x = scipy.linalg.solve(LU, P)`
# 4. `LU, P = np.linalg.solve(A, b); x = scipy.linalg.lu_solve((LU, P), b)`
#
# <!--  解答例
# 正解: 1
# 説明: LU分解を用いて連立方程式を解くには、`scipy.linalg.lu_factor` と `scipy.linalg.lu_solve` の組み合わせを使います。 -->
